# %% [markdown]
# <a href="https://colab.research.google.com/github/Hwaulat/computer-vision/blob/main/image_processing/ip_canny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import cv2

# %%
def funcCan(thresh1 = 0):
    thresh1 = cv2.getTrackbarPos('thresh1', 'canny')
    thresh2 = cv2.getTrackbarPos('thresh2', 'canny')
    edge = cv2.Canny(img, thresh1, thresh2)
    cv2.imshow('canny', edge)

# %%
if __name__== '__main__':

    original = cv2.imread("./jeruknipis.png",1)
    gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
    img = original.copy()
    img = cv2.GaussianBlur(img,(5,5),0)

    cv2.namedWindow('canny')

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 09.12.00.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 09.12.19.jpeg](data:image/jpeg;base64,...)

# %%
thresh1 = 0
    thresh2 = 0
    cv2.createTrackbar('thresh1','canny',thresh1,255,funcCan)
    cv2.createTrackbar('thresh2','canny',thresh2,255,funcCan)
    funcCan(0)
    cv2.imshow('Original', original)
    cv2.imshow('Blurred', img)
    cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 09.12.43.jpeg](data:image/jpeg;base64,...)

# %%
cv2.destroyAllWindows()
