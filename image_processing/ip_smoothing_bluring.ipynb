# %% [markdown]
# <a href="https://colab.research.google.com/github/Hwaulat/computer-vision/blob/main/image_processing/ip_smoothing_bluring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://riset.informatika.umm.ac.id/aguseko/batik1.jpg --no-check-certificate
# Out:
# --2021-10-06 10:55:49--  https://riset.informatika.umm.ac.id/aguseko/batik1.jpg
# Resolving riset.informatika.umm.ac.id (riset.informatika.umm.ac.id)... 202.52.52.30
# Connecting to riset.informatika.umm.ac.id (riset.informatika.umm.ac.id)|202.52.52.30|:443... connected.
# WARNING: cannot verify riset.informatika.umm.ac.id's certificate, issued by ‘CN=Sectigo RSA Domain Validation Secure Server CA,O=Sectigo Limited,L=Salford,ST=Greater Manchester,C=GB’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 34713 (34K) [image/jpeg]
# Saving to: ‘batik1.jpg’
#
# batik1.jpg          100%[===================>]  33.90K  --.-KB/s    in 0s
#
# 2021-10-06 10:55:50 (186 MB/s) - ‘batik1.jpg’ saved [34713/34713]

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import argparse
import cv2

# %%
def plt_imshow(title, image):
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %% [markdown]
# Average blurring (cv2.blur)

# %%
args = {
	"image": "jeruknipis.png"
}

# %%
image = cv2.imread(args["image"])
plt_imshow("Original", image)
kernelSizes = [(3, 3), (9, 9), (15, 15)]
# loop over the kernel sizes
for (kX, kY) in kernelSizes:
	# apply an "average" blur to the image using the current kernel
	# size
	blurred = cv2.blur(image, (kX, kY))
	plt_imshow("Average ({}, {})".format(kX, kY), blurred)
	cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.46.21.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.46.38.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.46.51.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.47.04 (1).jpeg](data:image/jpeg;base64,...)

# %%
cv2.destroyAllWindows()
for (kX, kY) in kernelSizes:
	# apply a "Gaussian" blur to the image
	blurred = cv2.GaussianBlur(image, (kX, kY), 0)
	plt_imshow("Gaussian ({}, {})".format(kX, kY), blurred)
	cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.50.14.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.50.28.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.50.45.jpeg](data:image/jpeg;base64,...)

# %%
cv2.destroyAllWindows()
for k in (3, 9, 15):
	# apply a "median" blur to the image
	blurred = cv2.medianBlur(image, k)
	plt_imshow("Median {}".format(k), blurred)
	cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.54.23.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.54.35.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.54.47.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Bilateral blurring (cv2.bilateralFilter)

# %%
params = [(11, 21, 7), (11, 41, 21), (11, 61, 39)]
# loop over the diameter, sigma color, and sigma space
for (diameter, sigmaColor, sigmaSpace) in params:
	# apply bilateral filtering to the image using the current set of
	# parameters
	blurred = cv2.bilateralFilter(image, diameter, sigmaColor, sigmaSpace)
	# show the output image and associated parameters
	title = "Blurred d={}, sc={}, ss={}".format(
		diameter, sigmaColor, sigmaSpace)
	plt_imshow(title, blurred)
	cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.55.01.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.55.12.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 06.55.24.jpeg](data:image/jpeg;base64,...)
