# %% [markdown]
# <a href="https://colab.research.google.com/github/Hwaulat/computer-vision/blob/main/image_processing/ip_adapative_thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
#inisialisasi image untuk dikonversi dan dipanggil nantinya
args = {
	"image": "jeruknipis.png"
}

# %%
#menggambil file gambar dan nampilkan
image = cv2.imread(args["image"])
plt_imshow("Image", image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 07.31.36.jpeg](data:image/jpeg;base64,...)

# %%
(T, threshInv) = cv2.threshold(blurred, 230, 255,
	cv2.THRESH_BINARY_INV)
plt_imshow("Simple Thresholding", threshInv)

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 07.31.55.jpeg](data:image/jpeg;base64,...)

# %%
thresh = cv2.adaptiveThreshold(blurred, 255,
	cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 21, 4)
plt_imshow("Gaussian Adaptive Thresholding", thresh)

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 07.32.07.jpeg](data:image/jpeg;base64,...)

# %%
thresh = cv2.adaptiveThreshold(blurred, 255,
	cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10)
plt_imshow("Mean Adaptive Thresholding", thresh)

# %% [markdown]
# ![WhatsApp Image 2021-11-08 at 07.32.21.jpeg](data:image/jpeg;base64,...)
