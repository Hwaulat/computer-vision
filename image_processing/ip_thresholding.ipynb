# %% [markdown]
# <a href="https://colab.research.google.com/github/Hwaulat/computer-vision/blob/main/image_processing/ip_thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://riset.informatika.umm.ac.id/aguseko/batik1.jpg --no-check-certificate
# Out:
# --2021-10-06 10:36:15--  https://riset.informatika.umm.ac.id/aguseko/batik1.jpg
# Resolving riset.informatika.umm.ac.id (riset.informatika.umm.ac.id)... 202.52.52.30
# Connecting to riset.informatika.umm.ac.id (riset.informatika.umm.ac.id)|202.52.52.30|:443... connected.
# WARNING: cannot verify riset.informatika.umm.ac.id's certificate, issued by ‘CN=Sectigo RSA Domain Validation Secure Server CA,O=Sectigo Limited,L=Salford,ST=Greater Manchester,C=GB’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 34713 (34K) [image/jpeg]
# Saving to: ‘batik1.jpg’
#
# batik1.jpg          100%[===================>]  33.90K  --.-KB/s    in 0s
#
# 2021-10-06 10:36:16 (91.5 MB/s) - ‘batik1.jpg’ saved [34713/34713]

# %%
import matplotlib.pyplot as plt
import argparse
import cv2

# %%
def plt_imshow(title, image):
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
args = {
	"image": "jeruknipis.png"
}

# %%
image = cv2.imread(args["image"])
plt_imshow("Image", image)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.01.06.jpeg](data:image/jpeg;base64,...)

# %%
# convert the image to grayscale and blur it slightly
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

# %%
(T, threshInv) = cv2.threshold(blurred, 200, 255,
	cv2.THRESH_BINARY_INV)
plt_imshow("Threshold Binary Inverse", threshInv)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.01.19.jpeg](data:image/jpeg;base64,...)

# %%
(T, thresh) = cv2.threshold(blurred, 200, 255, cv2.THRESH_BINARY)
plt_imshow("Threshold Binary", thresh)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.01.31.jpeg](data:image/jpeg;base64,...)

# %%
masked = cv2.bitwise_and(image, image, mask=threshInv)
plt_imshow("Output", masked)
cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.01.46.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Implementing Otsu thresholding with OpenCV

# %%
plt_imshow("Image", image)
# convert the image to grayscale and blur it slightly
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

(T, threshInv) = cv2.threshold(blurred, 0, 255,
	cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
plt_imshow("Threshold", threshInv)
print("[INFO] otsu's thresholding value: {}".format(T))

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.01.06.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.06.41.jpeg](data:image/jpeg;base64,...)

# %%
masked = cv2.bitwise_and(image, image, mask=threshInv)
plt_imshow("Output", masked)
cv2.waitKey(0)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 07.06.54.jpeg](data:image/jpeg;base64,...)
